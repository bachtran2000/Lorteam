# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
df = pd.read_csv('data_clean_train_NDT_24_10.csv',index_col=None)

# %%
df
# Out:
#                                                  Địa chỉ           Giá  \
# 0      \n        Dự án Mon City - Hải Đăng City, Đườn...  3.100000e+09
# 1      \n        Dự án Mỹ Đình Pearl, Đường Châu Văn ...  2.900000e+09
# 2      \n        Dự án Royal City, Đường Nguyễn Trãi,...  2.400000e+09
# 3      \n        Dự án Royal City, Đường Nguyễn Trãi,...  3.300000e+09
# 4      \n        Dự án Vinhomes Skylake, Đường Phạm H...  2.600000e+09
# ...                                                  ...           ...
# 10126  \n        Dự án HH1 Linh Đàm, Đường Linh Đường...  1.140000e+09
# 10127  \n        Dự án HH3 Linh Đàm, Đường Linh Đường...  1.280000e+09
# 10128  \n        Dự án Tecco Garden, Đường Quang Lai,...  1.880000e+09
# 10129   \n        Dự án KĐT Xa La, Hà Đông, Hà Nội\n      7.700000e+08
# 10130  \n        Eco Dream, số 300, Đường Nguyễn Xiển...  2.500000e+09
#
#        Diện tích  Số phòng ngủ  Số toilet Hướng nhà Hướng ban công  Nội thất  \
# ...

# %%
df.describe()
# Out:
#                 Giá     Diện tích  Số phòng ngủ     Số toilet      Nội thất  \
# count  1.013100e+04  10131.000000  10131.000000  10131.000000  10131.000000
# mean   3.002904e+09     88.376782      2.406673      1.966933      0.612378
# std    2.169605e+09     33.600101      0.689257      0.484704      0.487232
# min    5.000000e+00      5.000000      1.000000      1.000000      0.000000
# 25%    1.760000e+09     68.000000      2.000000      2.000000      0.000000
# 50%    2.600000e+09     83.000000      2.000000      2.000000      1.000000
# 75%    3.550000e+09    104.000000      3.000000      2.000000      1.000000
# max    5.500000e+10    700.000000      6.000000      6.000000      1.000000
#
#               Vĩ độ       Kinh độ
# count  10131.000000  10131.000000
# mean      20.989426    105.663599
# std        0.616656      3.876738
# min        5.000000      5.000000
# 25%       20.990440    105.783609
# 50%       21.006182    105.803230
# 75%       21.036568    105.831360
# ...

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='Số phòng ngủ',y='Giá',data=df)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='Số toilet',y='Giá',data=df)
plt.show()

# %%
df[df['Số toilet'] == 6]
# Out:
#                                                Địa chỉ           Giá  \
# 401  \n        Dự án Splendora An Khánh, Đường Đại ...  1.800000e+10
#
#      Diện tích  Số phòng ngủ  Số toilet Hướng nhà Hướng ban công  Nội thất  \
# 401      313.0             5          6       NaN            NaN         1
#
#                                             Chủ đầu tư Quy mô      Vĩ độ  \
# 401  Tổng công ty CP Xuất nhập khẩu và Xây dựng Việ...    NaN  21.015106
#
#         Kinh độ
# 401  105.724846

# %%
plt.figure(figsize=(20,10))
plt.scatter(df['Diện tích'],df['Giá'])
plt.xlabel('Diện tích')
plt.ylabel('Giá')
plt.show()

# %%
df = df[df['Giá']<3e10]

# %%
df = df[df['Diện tích'] < 400]

# %%
plt.figure(figsize=(20,10))
plt.scatter(df[(df['Diện tích'] > 250) & (df['Giá'] < 1.5e10)]['Diện tích'],df[(df['Diện tích'] > 250) & (df['Giá'] < 1.5e10)]['Giá'])
plt.xlabel('Diện tích')
plt.ylabel('Giá')
plt.show()

# %%
df[(df['Diện tích'] > 250) & (df['Giá'] < 1.5e10)]
# Out:
#                                                 Địa chỉ           Giá  \
# 634   \n        Dự án CT2 Trung Văn Viettel Hancic, ...  9.000000e+09
# 859   \n        Dự án Mandarin Garden, Đường Hoàng M...  1.400000e+10
# 1958  \n        Dự án Mandarin Garden, Đường Hoàng M...  1.400000e+10
# 2185  \n        Dự án Mandarin Garden, Phường Trung ...  1.450000e+10
# 2250  \n        Dự án Golden Palace, đường Mễ Trì, P...  1.300000e+10
# 2536  \n        Dự án Mandarin Garden, Đường Hoàng M...  1.400000e+10
# 2568  \n        Dự án Mandarin Garden, Đường Hoàng M...  1.400000e+10
# 2597  \n        Dự án Golden Palace, đường Mễ Trì, P...  1.300000e+10
# 7322  \n        Dự án Mandarin Garden, Đường Hoàng M...  1.400000e+10
# 7685  \n        Dự án Ecolife Tây Hồ, Đường Nguyễn V...  1.250000e+10
# 8111  \n        Dự án Mandarin Garden, Đường Hoàng M...  1.400000e+10
# 9954  \n        Dự án Ciputra Hà Nội, Đường Lạc Long...  1.100000e+10
#
# ...

# %%
df = df[df['KinhDo'] > 10]

# %%
plt.figure(figsize=(20,10))
sns.jointplot(x=df['ViDo'],y=df['KinhDo'],size=5)
plt.xlabel('ViDo',fontsize=12)
plt.ylabel('KinhDo',fontsize = 12)
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.figure(figsize=(20,10))
count,bin_edges = np.histogram(df['Số toilet'])
df['Số toilet'].plot(kind='hist',xticks=bin_edges)
plt.xlabel('Số Toilet')
plt.ylabel('Số lượng nhà')
plt.grid()
plt.show()
