# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
df = pd.read_csv('data_clean_train_16_11.csv',index_col=None)

# %%
df
# Out:
#        Index                                             TieuDe  \
# 0          0   CHÍNH CHỦ  BÁN CĂN HỘ CHUNG CƯ ECO LAKE VIEW ...
# 1          1                 RUBY CT3 PHÚC LỢI CHỈ TỪ 930 TRIỆU
# 2          2   MỞ BÁN ĐỢT 1 TÒA DIAMOND, ĐÃ CÓ SỔ HỒNG, GIÁ ...
# 3          3   SUẤT NGOẠI GIAO TẦNG 18 - CĂN HỘ SỐ 6 - 3 PHÒ...
# 4          4   SUNSHINE CITY CIPUTRA TÂY HỒ, CK 450TR, ĐÓNG ...
# ...      ...                                                ...
# 11159  11159   Chính chủ bán căn 01 tòa S3 2PN 75m2 đủ đồ, c...
# 11160  11160   Mở bán DA Harmony Square Nguyễn Tuân từ 2,78 ...
# 11161  11161   Chính chủ bán căn 114m2, 3 PN, đủ nội thất tò...
# 11162  11162   Bán CHCC cao cấp Tràng An Complex, Cầu Giấy, ...
# 11163  11163   CC mặt đường Nguyễn Tuân chỉ 2.7 tỷ căn 2PN, ...
#
#                                                      url  \
# 0      https://batdongsan.com.vn/ban-can-ho-chung-cu-...
# 1      https://batdongsan.com.vn/ban-can-ho-chung-cu-...
# ...

# %%
df = df.iloc[:,1:13]

# %%
df.describe()
# Out:
#               Index       GiaTien      DienTich    SoPhongNgu      SoToilet  \
# count  11164.000000  1.116400e+04  11164.000000  11164.000000  11164.000000
# mean    5581.500000  2.997979e+09     87.743613      2.417861      1.914457
# std     3222.913537  2.205000e+09     33.399818      0.695494      0.519210
# min        0.000000  2.800000e+06     21.000000      1.000000      0.000000
# 25%     2790.750000  1.700000e+09     67.000000      2.000000      2.000000
# 50%     5581.500000  2.600000e+09     82.300000      2.000000      2.000000
# 75%     8372.250000  3.552500e+09    103.000000      3.000000      2.000000
# max    11163.000000  3.500000e+10    789.000000      6.000000      6.000000
#
#             NoiThat          ViDo        KinhDo
# count  11164.000000  11164.000000  11164.000000
# mean       1.027857     21.013058    105.812899
# std        0.639718      0.033973      0.047909
# min        0.000000     20.880546    105.584796
# ...

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='SoPhongNgu',y='GiaTien',data=df)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.hist(df['SoPhongNgu'])
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.displot(df['DienTich'],bins=50)
plt.show()

# %%
df[df['SoToilet'] ==0]
# Out:
#       Index                                             TieuDe  \
# 444     444   Bán gấp Skyvilla 2 tầng và 4PN 170m2 - 330m2 ...
# 7881   7881   Cần bán căn hộ penhouse, 355m2, 4 phòng ngủ, ...
# 9533   9533   Bán Penhouse 467,5m2 Golden Palace 4PN 2PK bế...
#
#                                                     url  \
# 444   https://batdongsan.com.vn/ban-can-ho-chung-cu-...
# 7881  https://batdongsan.com.vn/ban-can-ho-chung-cu-...
# 9533  https://batdongsan.com.vn/ban-can-ho-chung-cu-...
#
#                                                   ViTri         Quan  \
# 444   \n        Dự án Vinhomes Skylake, Đường Phạm H...  Nam Từ Liêm
# 7881  \n        Sông Đà 7, số 5, Đường Tú Mỡ, Phường...     Cầu Giấy
# 9533  \n        Dự án Golden Palace, Đường Đồng Me, ...  Nam Từ Liêm
#
#            GiaTien  DienTich  SoPhongNgu  SoToilet  \
# 444   2.200000e+10     330.0           5         0
# 7881  9.700000e+09     355.0           4         0
# ...

# %%
df.drop(9533,axis=0,inplace=True)

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='SoToilet',y='GiaTien',data=df)
plt.show()

# %%
df[df['NumberToilet'] == 6]
# Out:
#              Price   Area  NumberBed  NumberToilet  HuongNha HuongBanCong  \
# 4546  1.800000e+10  313.0          5             6   Tây-Bắc     Đông-Nam
# 8967  5.200000e+09  235.0          5             6  Đông-Nam      Tây-Bắc
#
#       NoiThat                                           Chudautu       QuyMo  \
# 4546  Đầy đủ.  Tổng công ty CP Xuất nhập khẩu và Xây dựng Việ...         NaN
# 8967      NaN                                  Tập đoàn Vingroup  Gồm: 6 tòa
#
#            ViDo      KinhDo     LoaiTin
# 4546  21.015106  105.724846  Tin thường
# 8967  21.002666  105.815430  Tin thường

# %%
df[df['DienTich'] > 700]
# Out:
#      Index                                             TieuDe  \
# 336    336   Bán Penthouse Duplex trên 700m2 đẳng cấp Hà N...
#
#                                                    url  \
# 336  https://batdongsan.com.vn/ban-can-ho-chung-cu-...
#
#                                                  ViTri         Quan  \
# 336  \n        Dự án The Matrix One, Đường Lê Quang...  Nam Từ Liêm
#
#           GiaTien  DienTich  SoPhongNgu  SoToilet  \
# 336  2.600000e+10     789.0           5         6
#
#                                                HinhAnh  ... HuongBanCong  \
# 336  ['https://file4.batdongsan.com.vn/2020/11/12/2...  ...      Tây-Nam
#
#     NoiThat                                               MoTa ChuDauTu QuyMo  \
# 336       1  \n                Bán căn Penthouse Duplex trê...      NaN   NaN
#
#           ViDo      KinhDo    NgayDang    LoaiTin   DienThoai
# 336  21.009993  105.773422  12/11/2020  Tin Vip 3  0901986222
#
# [1 rows x 21 columns]

# %%
df.drop(336,axis=0,inplace=True)

# %%
plt.figure(figsize=(20,10))
plt.scatter(df['DienTich'],df['GiaTien'])
plt.xlabel('Diện tích')
plt.ylabel('Giá')
plt.show()

# %%
df[(df['Area'] > 250) & (df['Price']<1.5e10)]
# Out:
#               Price   Area  NumberBed  NumberToilet  HuongNha HuongBanCong  \
# 499    5.700000e+09  285.0          5             4  Đông-Bắc      Tây-Nam
# 542    1.250000e+10  364.0          5             4   Tây-Nam     Đông-Bắc
# 1249   3.800000e+09  295.0          5             4   Tây-Nam     Đông-Bắc
# 2754   1.100000e+10  330.0          5             4   Tây-Bắc     Đông-Nam
# 3007   1.200000e+10  273.0          5             4   Tây-Bắc     Đông-Nam
# 3148   1.450000e+10  268.0          4             4   Tây-Nam     Đông-Bắc
# 4997   5.600000e+09  340.0          4             3       Nam          Bắc
# 5257   4.200000e+09  295.0          4             2   Tây-Nam     Đông-Bắc
# 5374   1.220000e+10  375.6          6             4  Đông-Nam      Tây-Bắc
# 5676   1.400000e+10  268.0          4             4   Tây-Bắc     Đông-Nam
# 5908   3.800000e+09  296.0          5             4      Đông          Tây
# ...

# %%
plt.figure(figsize=(20,10))
count,bin_edges = np.histogram(df['NumberBed'])
df['NumberBed'].plot(kind='hist',xticks=bin_edges)
plt.xlabel('Giá')
plt.ylabel('Số lượng nhà')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,10))
count,bin_edges = np.histogram(df['NumberToilet'])
df['NumberToilet'].plot(kind='hist',xticks=bin_edges)
plt.xlabel('Giá')
plt.ylabel('Số lượng nhà')
plt.grid()
plt.show()
